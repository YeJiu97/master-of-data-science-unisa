# %% [markdown]
# **PyMuPDF + pyttesseract**

# %%
import fitz  # PyMuPDF
from PIL import Image
import pytesseract
import io

#Specify the installation path of Tesseract and modify it according to your actual installation location
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'  # Windows
# pytesseract.pytesseract.tesseract_cmd = '/usr/bin/tesseract'  # Linux

def pdf_to_text(pdf_path):
    #Open PDF file
    doc = fitz.open(pdf_path)
    text = ''
    
    for page_num in range(len(doc)):
        # Get the image list of a single page
        page = doc.load_page(page_num)
        pix = page.get_pixmap()
        img = Image.open(io.BytesIO(pix.tobytes()))

        # Use OCR to extract text from images
        page_text = pytesseract.image_to_string(img, lang='eng')
        text += page_text + '\n'
    
    return text

pdf_path = '236-020-SAS-120_0.pdf'  # Please modify the path according to the actual situation
extracted_text = pdf_to_text(pdf_path)
print(extracted_text)
# Out:
# ADBRI BIRKENHEAD 1000T RMS SILO
#
# SILO ROOF HATCH
#
# ISOMETRIC VIEW
# HATCH CLOSED
#
# NOTES:
#
# 1. REFER TO 236-020-SAS-001 FOR ASSEMBLY DETAILS, 236-020-GEN-001 FOR GENERAL NOTES & 236-020-RPT-001
#
# 2. WELD LINES TO BE OFFSET AS PER STANDARDS,
# 3. SURFACE TREATMENT AS PER GENERAL NOTES DWG 236-020-GEN-001
# 4, IF IN DOUBT, ASK
#
# WELDED NUT AND BOLT TO
# “RETAIN GRATING
#
# EXTERNAL ISOMETRIC
#
# BOM - GENERAL ASSEMBLY
# ITEM ary PART NUMBER DESCRIPTION DETAILED DRAWING
# 1 1 236-020-WAS-157 HATCH DOOR ASSEMBLY 236-020-WAS-157
# 2 1 236-020-WAS-158 HATCH BASE ASSEMBLY 236-020-WAS-158
# 3 1 236-020-PRT-122 WEBFORGE GRATING D253 236-020-PRT-122
#
# 4 2 AS 1237 - 8 mm WASHER FLAT MB
#
# 5 1 AS 1112 - MB HEX NUT MB
#
# 6 1 AS 1110 - M8 x 35 HATCH LOCK BOLT MB
#
# 7 rs TAS 1237 - 12 mm WASHER FLAT M12
#
# 8 2 AS 1110 - M12 x 35 HINGE BOLT M12,
#
# 3 4 AS 1112 - M12, HEX NUT M12
#
# 10 4 AS 1110 - M12 x 25 M12 BOLT, GRATING RETAINER
#
# 1 1 236-020-PRT-116 EPDM SPONGE SEAL 32 x 25 SITE FIT
#
# TOTAL MASS = 211 kg
#
# HATCH OPEN ISOMETRIC VIEW
# (1:75) HATCH OPEN W GRATING REMOVED
# (1:75)
# AL Saws" ISSUED FOR CONSTRUCTION
# e Drawn AZ [Baie 1810172023 | As Seam = 15x] At Suet Sa =| 1:5
# : INgeNIa Desert 1000T RMS SILO
# as en rae SILO ROOF HATCH
# enoast ae” | e GENERAL ASSEMBLY
# (© | 2oar2023 | ISSUED FOR CONSTRUCTION DP HV | OH HV fee ‘Genius Consulting Py Li, ABN 91615 110 033 Cts Code |_Job Number_|___Type__{_Drawing_|_Sheet_{ Revisio
# REV| DATE REVISION HISTORY DRN CHK/ENG| PM femene: 2600 \aetn’sa sit nmownaconn _ 286 + O20 > SAS + 120-01. 0
#
# 9, SSIES STS ES Pi SERRA STS PAY HGS RTE SHES TE SAY HET TTT
#
# Sa a aw eT aS WT PARE WT, Gas AY Sa EPO oy pai who ay say en Wi TE aa aon coined eran Ti
#
# ig TTS BES, posure arene] DWTS @ WF, SATS TASS danse eal Gan par, Mave of MaRS, MEGA EPI A WH PSR od
#
# (DRAWINGS NOT APPROVED UNLESS APPROVAL SIGNATURES PRESENT O:AZiingeniai236-020 ABC RMS Sio - Documents\O4-CADIO2-DrawingsiWorkshop IFCIDWGW236-020-SAS-120 dwg
#
# ADBRI BIRKENHEAD 1000T RMS SILO
#
# SILO ROOF HATCH
#
# a]
# a
#
# 370
#
# 370
#
# 162
#
# SIDE VIEW
# (1:5)
#
# TOP VIEW
# ITEM: 236-020-SAS-120
#
# NOTES:
#
# if io
# LEA] ale
# TW
# A A
# f) CT)
# y {yf o Wt
# LI 3 as
#
# 1. REFER TO 236-020-SAS-001 FOR ASSEMBLY DETAILS, 236-020-GEN-001 FOR GENERAL NOTES & 236-020-RPT-001
#
# 2. WELD LINES TO BE OFFSET AS PER STANDARDS,
# 3. SURFACE TREATMENT AS PER GENERAL NOTES DWG 236-020-GEN-001
# 4, IF IN DOUBT, ASK
#
# A-A(1:2)
# SPONGE SEAL DETAIL
#
# EXTERNAL ISOMETRIC
# (1:5)
#
# BOM - GENERAL ASSEMBLY
# ITEM ary PART NUMBER DESCRIPTION DETAILED DRAWING
# 1 1 236-020-WAS-157 HATCH DOOR ASSEMBLY 236-020-WAS-157
# 2 1 236-020-WAS-158 HATCH BASE ASSEMBLY 236-020-WAS-158
# 3 1 236-020-PRT-122 WEBFORGE GRATING 0253 236-020-PRT-122
#
# 4 2 AS 1237 - 8 mm WASHER FLAT MB
#
# 5 1 AS 1112 - M8 HEX NUT MB
#
# 6 1 AS 1110 - M8 x 35 HATCH LOCK BOLT M8
#
# 7 & AS 1237 - 12 mm "WASHER FLAT M12
#
# 8 2 AS 1110 - M12 x 35 HINGE BOLT M12
#
# 9 4 AS 1112 - M12 HEX NUT M12
#
# 10 & AS 1110 - M12 x 25 M12 BOLT, GRATING RETAINER
#
# 1 1 236-020-PRT-116 EPDM SPONGE SEAL 32 x 25 SITE FIT
#
# 25
#
# ~—WEBFORGE MESH
# TOP VIEW. SIDE VIEW
# ITEM: 236-020-PRT-122 (1:8)
# INTERNAL ISOMETRIC WEBFORGE D253
# (1:5) (1:8)
# At Saws" ISSUED FOR CONSTRUCTION
#
# e Deen AZ [ose 18012023 [sass =15s]AiSonéab=[ 1
# IN eNI a Deron: 1000T RMS SILO
# SILO ROOF HATCH
# e GENERAL ASSEMBLY
#
# Gini Cade | Job Number | Type
#
# | 20/04/2028 | ISSUED FOR CONSTRUCTION DP HV | DH | HV Gonius Consulting Py Lid, ABN 91 615 110 033
#
# Drawing
#
# ‘Shest_| Revisor
#
# REV) DATE REVISION HISTORY DRN|CHK/ENG] PM
#
# few: 296000 Mluctna’Sa'ststnmtgenacens _ 230 + 020 - SAS - 120-02. 0
#
# Sg, SSIES Ss SES Pi SEPT SOEs PA GAS SEE BHP TS ATES HAE” SST Sis HSTGN SSS HS RS SASHES SOSA WSIS WSUS TS SEONG, aT AY 3 SERIE HS SPORE TH YW ma as ayn Wi RSG Ra Hasson conser THe WAS
#
# ap osices farang DWTS @ WF, SSTTRST TADS danoeed eal an par, Mrave of MARISSA, EGA EPI A WH PGR
#
# (DRAWINGS NOT APPROVED UNLESS APPROVAL SIGNATURES PRESENT O:AZiingeniai236-020 ABC RMS Sio - Documents\O4-CADIO2-DrawingsiWorkshop IFCIDWGW236-020-SAS-120 dwg

# %%
import fitz  # PyMuPDF
from PIL import Image
import pytesseract
import io

# We will skip setting the pytesseract.tesseract_cmd because it's not needed in this environment.
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'  # Windows

def pdf_to_text(pdf_path):
    # Open PDF file
    doc = fitz.open(pdf_path)
    text = ''
    
    for page_num in range(len(doc)):
        # Get the pixmap of the entire page (image)
        page = doc.load_page(page_num)
        pix = page.get_pixmap()
        
        # Convert the pixmap to an image object
        img = Image.open(io.BytesIO(pix.tobytes()))
        
        # Use OCR to extract text from the image
        page_text = pytesseract.image_to_string(img, lang='eng')
        text += page_text + '\n'
    
    # We'll only keep the text from the first page since the content is the same on every page
    return text.split('\n\n')[0]

# Path to the PDF file
pdf_path = '236-020-SAS-120_0.pdf'

# Extract text using OCR
extracted_text = pdf_to_text(pdf_path)
extracted_text

# %% [markdown]
# **PyMuPDF + Keras_OCR**

# %%
import fitz #PyMuPDF
import keras_ocr

# Initialize the pipeline of keras-ocr
pipeline = keras_ocr.pipeline.Pipeline()

#Open PDF file
pdf_path = '236-020-SAS-120_0.pdf'
pdf_document = fitz.open(pdf_path)

# Traverse each page of the PDF document
for page_num in range(len(pdf_document)):
     # Get the page
     page = pdf_document.load_page(page_num)
    
     # Convert PDF pages to images (pix)
     pix = page.get_pixmap()
    
     # Save image directly to file
     image_path = f"page_{page_num + 1}.png"
     pix.save(image_path)
    
     # Use keras-ocr to read the saved image and recognize the text
     image = keras_ocr.tools.read(image_path)
     predictions = pipeline.recognize([image])[0]
    
     #Print prediction results
     print(f"Page {page_num + 1}:")
     for text, _ in predictions:
         print(text)

pdf_document.close()
# Out:
# Looking for C:\Users\Wangjun\.keras-ocr\craft_mlt_25k.h5
# Looking for C:\Users\Wangjun\.keras-ocr\crnn_kurapan.h5
# 1/1 [==============================] - 7s 7s/step
# 8/8 [==============================] - 10s 996ms/step
# Page 1:
# bom
# general
# assembl
# adbri
# birkenhead
# 1000t
# rms
# silo
# number
# descrip
# drawing
# part
# ton
# detailed
# f6
# 0z0
# was
# 11
# hach
# door
# assemel
# 16
# ozowas
# 151
# ozowasaes
# hatch
# base
# assemel
# ozowasass
# silo
# roof
# hatch
# bozoprzz
# wedforge
# grating
# d258
# 6ozopr1z
# vashere
# 211
# flat
# m6
# s
# 125
# hex
# nut
# mb
# s
# 110
# moxes
# hatch
# lock
# dolt
# m0
# s
# 211
# 12
# vasherflat
# m12
# mm
# as
# 110s
# m12x65
# hinge
# bolt
# m1z
# as
# 122
# m12
# hexnut
# m12
# as
# 110
# mi2xz5
# m12
# boll
# grating
# retainer
# 266
# ozoprl6
# epdm
# sponge
# seal
# sitefit
# szx
# 15
# total
# mass
# 211
# kg
# s
# danger
# sin
# s
#
# satmetric
# closed
#
# wel
# ded
# not
# and
# bol
# to
# grating
# fe
# tan
# e
# external
# isome
# tric
# hatch
# open
# s
# isome
# tric
# tine
# 75
# te
# hatch
# open
# gra
# removed
# w
# i
# e
#
# e
# sucle
# issued
# for
# consroction
# s
# notes
# doot
# slall
# teuneoes
# celea
# ingenia
# lealelan
# doot
# rms
# silo
# re
# fer
# o
# 2b0z0
# sa
# soo1
# for
# assembl
# details
# 50
# d2o
# genfoot
# for
# general
# notes
# 250
# ozore
# od1
# men
#
# hatch
# silo
# roof
# weld
# lines
# to
# be
# offser
# as
# per
# standards
# general
# ass
# embl
# ws
# surface
# treatment
# as
# per
# general
# notes
# diwg
# 250
# 020
# genni
# 001
# clent
# de
# srpe
# damn
# snee
# fevison
# if
# doubt
# ask
# ir
# cons
# unos
# cols
# ssued
# fon
# cons
# leuel
# acmaon
# seelicesinec
# to
# hanoy
# boncn
# ro
# phagie
# tz
# sero
# 236
# 020
# sas
# 120
# o
# revision
# hist
# ory
# chk
# eng
# pm
# dalle
# zoelro
# lole
# end
# sa
# stenaconn
# dtot
# elenlenle
# ano
# d
# aamelore
# caee
# odlede
# lecaloray
# nenmales
# dolliiet
# melen
# eee
# saais
# ernenal
# rn
# fupaees
# 1/1 [==============================] - 5s 5s/step
# 9/9 [==============================] - 7s 799ms/step
# Page 2:
# bom
# general
# assembly
# adbri
# birkenhead
# 1000t
# rms
# silo
# number
# descrip
# detailed
# part
# ton
# drawing
# 26
# ozoawas
# 151
# hach
# door
# assembly
# 86e
# ozowase
# 151
# ozowasss
# halch
# base
# assembly
# bozowasss
# silo
# roof
# hatch
# bgozor1zz
# webforge
# grating
# d258
# b6ozopri1zz
# washer
# as
# 21
# flat
# mb
# mm
# as
# 1122
# mb
# ex
# nut
# m8
# as
# 10
# moxes
# hatchlock
# bolt
# m0
# s
# 211
# washerflat
# m12
# tz
# mm
# as
# 10
# m12x
# hinge
# bolt
# 85
# mz
# as
# 1122
# m12
# hex
# nut
# m12
# as
# 10
# m12x25
# mzbolt
# grating
# retainer
# bbozopri1
# epdm
# sponge
# seal
# 2x25
# site
# fit
# aatte
# z
# hawasonsino
# ansidashing
# sponge
# seal
# detail
# dednva
# 762
# side
# view
# 1151
#
# s
#
# external
# isome
# tric
# 51
# jao
# e
# s
# i
# e
# top
# view
# webforge
# mesh
# items
# 236
# 020
# sas120
# 115
# top
# view
# view
# side
# 020
# item
# webforoge
# prt
# 122
# 8
# internal
# isome
# tric
# 8
# t5
# 5
# e
# issued
# for
# consroction
# s
# notes
# lonot
# slall
# teuneoes
# celen
# ingenia
# lealelan
# doot
# rms
# silo
# re
# fer
# o
# 2b0z0
# sa
# soo1
# for
# assembl
# details
# 50
# d2o
# genfoot
# for
# general
# notes
# 250
# 020
# re
# od1
# men
#
# hatch
# silo
# roof
# weld
# as
# lines
# to
# be
# offser
# per
# standards
# general
# ass
# embl
# ws
# surface
# treatment
# as
# per
# general
# notes
# diwg
# 250
# 020
# genni
# 001
# clent
# de
# srpe
# damn
# snee
# fevison
# if
# doubt
# ask
# ir
# cons
# abn
# unos
# cols
# ssued
# fon
# cons
# hucn
# acmaon
# seelicesinec
# to
# hanoy
# boncn
# ro
# phagie
# tz
# sero
# 236
# 020
# sas
# 120
# 02
# revision
# hist
# ory
# chk
# eng
# pm
# dalle
# zoelro
# lole
# end
# sa
# stenaconn
# dtot
# elenlenle
# ano
# d
# eee
# daneee
# odlede
# lecaloray
# nenmales
# dolliiet
# melen
# loas
# eee
# saais
# ernenal
# rn
# fupaees

# %%
import fitz #PyMuPDF
import easyocr
import numpy as np
from PIL import Image

#Create a reader instance of easy-ocr
reader = easyocr.Reader(['en']) # You can add other languages as needed

#Open PDF file
pdf_path = '236-020-SAS-120_0.pdf'
pdf_document = fitz.open(pdf_path)

# Traverse each page of the PDF document
for page_num in range(len(pdf_document)):
     # Get the page
     page = pdf_document.load_page(page_num)
    
     # Convert PDF pages to images
     pix = page.get_pixmap()
    
     # Convert the image to byte array and load it into the PIL Image object
     img = Image.open(BytesIO(pix.tobytes()))
    
     # Convert PIL Image to numpy array, because easy-ocr requires images in numpy array format
     np_img = np.array(img)
    
     # Use easy-ocr to identify text in images
     results = reader.readtext(np_img)
    
     #Print recognition results
     print(f"Page {page_num + 1}:")
     for (bbox, text, prob) in results:
         print(f"Detected text: {text} with confidence {prob}")

pdf_document.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 22
#      19 pix = page.get_pixmap()
#      21 # Convert the image to byte array and load it into the PIL Image object
# ---> 22 img = Image.open(BytesIO(pix.tobytes()))
#      24 # Convert PIL Image to numpy array, because easy-ocr requires images in numpy array format
#      25 np_img = np.array(img)
#
# NameError: name 'BytesIO' is not defined

# %% [markdown]
# **if use pdf2image**
