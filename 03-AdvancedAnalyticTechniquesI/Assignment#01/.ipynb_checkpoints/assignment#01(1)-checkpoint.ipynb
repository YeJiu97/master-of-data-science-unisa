# %% [markdown]
# ## Question 1

# %% [markdown]
# **Take the solar radiation data from File a, and copy it into File c, and run the
# power spectrum tool to find out which frequencies are important**.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

solar_radia2017 = pd.read_excel('HalfHourSolarRadiation2017.xlsx',sheet_name='Sheet1')

# %% [markdown]
# Discrete Fourier transform, using the power value as a measure of power in solar radiation

# %%
import math

def calculate_dft(data, num_frequencies):
    num_data = len(data)
    n2 = num_data / 2
    ret = {'frequency': [], 'ai': [], 'bi': [], 'power': []}
    
    for i in range(1,num_frequencies+1):
        s1 = 0
        s2 = 0
        s0 = sum(data)
        
        for j in range(1,num_data):
            angle = math.pi * i / n2 * (j + 1)
            cit = math.cos(angle)
            sit = math.sin(angle)
            s1 += cit * data[j]
            s2 += sit * data[j]
        
        s1 /= n2
        s2 /= n2
        
        ret['frequency'].append(i)
        ret['ai'].append(s1)
        ret['bi'].append(s2)
        ret['power'].append(s1 ** 2 + s2 ** 2)
    
    ret['ai'][0] = sum(data) / len(data)
    return pd.DataFrame(ret)

# %% [markdown]
# Based on the GHI column, calculate the power corresponding to different frequencies

# %% [markdown]
# Notice: a large frequencies value may causes jupyter lab crashes.

# %%
num_frequencies = 50

PS_result2017 = calculate_dft(solar_radia2017.GHI, num_frequencies)
PS_result2017
# Out:
#     frequency          ai         bi         power
# 0           1  171.037166  14.970197  16785.192278
# 1           2    4.495565   5.587824     51.433878
# 2           3    1.914398  -3.030740     12.850306
# 3           4    7.799192  -9.905761    158.951499
# 4           5    8.008929   9.426698    153.005577
# 5           6   -6.382498   1.815368     44.031845
# 6           7    4.971753  -4.086769     41.420008
# 7           8   -0.540952  15.997302    256.206287
# 8           9   -9.827451  -0.908250     97.403710
# 9          10    2.797006  -9.896678    105.767476
# 10         11    5.743525   3.677180     46.509732
# 11         12  -10.574423  -2.082418    116.154878
# 12         13   -2.415825  -2.184167     10.606797
# 13         14    0.318859  -3.137737      9.947063
# 14         15    3.425715  -8.385859     82.058148
# 15         16    7.144505   7.100577    101.462139
# 16         17    7.758114   4.839201     83.606203
# ...

# %%
#find out which frequencies are important

PS_result2017.sort_values(by=['power'],ascending=False,inplace=True)
print(PS_result2017)

plt.figure(figsize=(16,9))
plt.bar(PS_result2017['frequency'], PS_result2017['power'])
plt.title('Power Spectrum Result - HalfHourSolarRadiation2017', fontsize=14)
plt.xlabel('Frequency', fontsize=14)
plt.ylabel('Power', fontsize=14)
plt.grid(True)
plt.show()

#we can identify 5 important frequencies from the below result and chart
important_frequencies = PS_result2017['frequency'][:5].values
print('we can identify that 5 most important frequencies are: ',important_frequencies)
# Out:
#     frequency          ai         bi         power
# 0           1  171.037166  14.970197  16785.192278
# 7           8   -0.540952  15.997302    256.206287
# 44         45  -10.536356  -9.501684    201.296783
# 42         43   11.249041  -6.374717    167.177935
# 3           4    7.799192  -9.905761    158.951499
# 4           5    8.008929   9.426698    153.005577
# 34         35  -11.768945  -1.809064    141.780788
# 21         22    5.623170  10.070559    133.036195
# 18         19   -4.101640 -10.779385    133.018597
# 11         12  -10.574423  -2.082418    116.154878
# 9          10    2.797006  -9.896678    105.767476
# 15         16    7.144505   7.100577    101.462139
# 20         21   -3.396156   9.305048     98.117798
# 8           9   -9.827451  -0.908250     97.403710
# 33         34    5.017358   7.943469     88.272587
# 28         29    1.205559  -9.112865     84.497683
# 16         17    7.758114   4.839201     83.606203
# ...

# %% [markdown]
# **Use File c to find the Fourier series model for the seasonality. Note that the
# Template is designed for hourly data. You will have to make some adjustment
# to use it for half hourly data plus change the relevant frequencies if necessar**y.

# %%
#Define time intervals for half-hourly data
time_intervals = np.arange(1,solar_radia2017.shape[0]+1)

# setting frequencies
frequencies = [1,364,365,366,730]
a_list = [-128.6899753,87.08261942,-263.346882,90.51225331,109.2062286]
b_list = [14.97013864,1.911366892,21.43218589,-17.0102398,-17.22103819]

def calculate_fourier_series(data, t, frequencies):
    fsm_result = pd.DataFrame(columns=['data','t'])
    fsm_result['data'] = data
    fsm_result['t'] = t
    
    for i in range(len(frequencies)):
        freq_results = []
        w = 2 * np.pi * frequencies[i] / len(data)
        for j in range(len(data)):
            freq_result = a_list[i]*np.cos(w * t[j]) + b_list[i]*np.sin(w * t[j]) 
            freq_results.append(freq_result)
        fsm_result[str(frequencies[i])] = freq_results
    
    fsm_result['model'] = np.mean(data)+fsm_result['1']+fsm_result['364']+fsm_result['365']+fsm_result['366']+fsm_result['730']
    return fsm_result

# %%
#Fourier series model result
FS_2017 = calculate_fourier_series(solar_radia2017['GHI'],time_intervals,frequencies)
FS_2017
# Out:
#        data      t           1        364         365        366         730  \
# 0       0.0      1 -128.684598  86.590490 -258.296451  87.507336  101.027984
# 1       0.0      2 -128.679205  84.624869 -248.826497  82.996940   85.964849
# 2       0.0      3 -128.673795  81.219205 -235.099052  77.058663   65.043352
# 3       0.0      4 -128.668368  76.431452 -217.348997  69.794666   39.689258
# 4       0.0      5 -128.662925  70.343081 -195.880040  61.329920   11.630406
# ...     ...    ...         ...        ...         ...        ...         ...
# 17515   0.0  17516 -128.711318  74.524836 -238.781183  86.847153   69.516971
# 17516   0.0  17517 -128.706007  79.760109 -251.502537  90.111545   89.397578
# 17517   0.0  17518 -128.700680  83.638122 -259.920612  91.825656  103.185887
# 17518   0.0  17519 -128.695336  86.092883 -263.891375  91.959996  109.942249
# 17519   0.0  17520 -128.689975  87.082619 -263.346882  90.512253  109.206229
#
#            model
# 0      59.181927
# ...

# %% [markdown]
# **Take the difference between the data and the Fourier model - the residuals -
# and take them to Minitab and find the best ARMA(p,q) model**.y.

# %%
#Find the best ARMA(p,q) model based on AIC。
# Specifically, use the AIC criterion to estimate the parameters of the ARMA model, ie (p, q)
# and traverse the model parameters that minimize the AIC value

import statsmodels.api as sm
from statsmodels.tsa.arima_model import ARMA

# Calculate the residuals
FS_2017['residual'] = FS_2017['data'] - FS_2017['model']

# Use the AIC criterion to estimate the parameters of the ARMA model, that is, (p, q)
# and traverse the model parameters that minimize the AIC value.

AIC_value = []

for ari in range(0,5):
    for maj in range(0,5):
        try:
            arma_object = ARMA(FS_2017['residual'],order=(ari,maj)).fit()
            AIC_value.append([ari,maj,arma_object.aic])
        except:
            print('wrong parameters')

print(AIC_value)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# ...

# %% [markdown]
# According to the results, when (p, q) = (4, 0), the AIC value is the smallest. Therefore, (4,0) is the best model parameter for ARMA.

# %%
# get the best model
best_arma = ARMA(FS_2017['residual'].tolist(),order=(4,0)).fit()
print(best_arma.summary())
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
#                               ARMA Model Results
# ...

# %% [markdown]
# The provided output represents the results of an ARMA (AutoRegressive Moving Average) model with a specification of ARMA(4, 0). This model is commonly employed in time series analysis, often applied to various domains such as finance and economics. It is essential to delve into a comprehensive description of the key components and statistical metrics derived from this model estimation.
#
# The dataset used for this analysis comprises 17,520 observations, and the ARMA(4, 0) model is designed to capture the underlying patterns and relationships within this time series data. The ARMA notation signifies the combination of autoregressive (AR) and moving average (MA) components, with the numbers in parentheses indicating the order of these components. In this specific model, there are four autoregressive terms (AR) and zero moving average terms (MA).
#
# To assess the goodness of fit of the model, several crucial statistical metrics are examined. The Log Likelihood, with a value of -92153.252, represents the logarithm of the likelihood function and serves as an indicator of how well the model fits the data. A higher Log Likelihood value generally implies a better fit.
#
# The Standard Deviation of Innovations, which measures the standard deviation of the model's residuals (innovations), is reported as 46.568. It provides insight into the magnitude of prediction errors, with a higher value indicating larger forecast errors.
#
# Additionally, two widely used model selection criteria are presented: the Akaike Information Criterion (AIC) and the Bayesian Information Criterion (BIC). Lower AIC and BIC values, 184318.504 and 184365.131, respectively, suggest a better model fit, with the latter applying a penalty for model complexity.
#
# The Hannan-Quinn Information Criterion (HQIC), another model selection criterion, yields a value of 184333.858. Like AIC and BIC, lower HQIC values indicate superior model performance, considering both fit and complexity.
#
# Moving on to the model's parameter estimates, it is crucial to interpret their significance. The "const" term, representing the intercept or constant coefficient, is estimated as -0.0366, with a p-value of 0.990. The p-value indicates whether this constant term is statistically significant; in this case, the high p-value suggests that the constant may not be significant and could potentially be omitted from the model.
#
# The autoregressive coefficients, denoted as "ar.L1.y" through "ar.L4.y," represent the strength and direction of the lagged relationships within the time series data. The values are estimated as 0.8732, 0.0654, -0.0197, and -0.0424, respectively. These coefficients describe how past observations influence future values in the time series. Their significance is assessed through p-values, and in this instance, all autoregressive coefficients have p-values below 0.05, indicating their statistical significance.
#
# Finally, the model provides information about the roots of the autoregressive component. These roots represent the characteristic roots of the model, offering insights into its dynamic behavior.
#
# In conclusion, this ARMA(4, 0) model estimation results in the identification of autoregressive relationships within a time series dataset. It encompasses critical statistical metrics and parameter estimates, with significance assessments based on p-values.

# %% [markdown]
# **Use the ARMA model to forecast one step ahead for the residuals and add that to the Fourier series model to get the full one step ahead forecast.**

# %%
#forecast one step ahead for the residuals
FS_2017['pred_residuals'] = best_arma.predict(0,FS_2017.shape[0]-1)

#add that to the Fourier series model
FS_2017['pred_GHI'] = FS_2017['model'] + FS_2017['pred_residuals']
FS_2017
# Out:
#        data      t           1        364         365        366         730  \
# 0       0.0      1 -128.684598  86.590490 -258.296451  87.507336  101.027984
# 1       0.0      2 -128.679205  84.624869 -248.826497  82.996940   85.964849
# 2       0.0      3 -128.673795  81.219205 -235.099052  77.058663   65.043352
# 3       0.0      4 -128.668368  76.431452 -217.348997  69.794666   39.689258
# 4       0.0      5 -128.662925  70.343081 -195.880040  61.329920   11.630406
# ...     ...    ...         ...        ...         ...        ...         ...
# 17515   0.0  17516 -128.711318  74.524836 -238.781183  86.847153   69.516971
# 17516   0.0  17517 -128.706007  79.760109 -251.502537  90.111545   89.397578
# 17517   0.0  17518 -128.700680  83.638122 -259.920612  91.825656  103.185887
# 17518   0.0  17519 -128.695336  86.092883 -263.891375  91.959996  109.942249
# 17519   0.0  17520 -128.689975  87.082619 -263.346882  90.512253  109.206229
#
# ...

# %%
plt.figure(figsize=(16,9))
plt.plot(FS_2017['t'],FS_2017['data'],label='original')
plt.plot(FS_2017['t'],FS_2017['pred_GHI'],label='predict')
plt.title('Original V.S Predict - HalfHourSolarRadiation2017')
plt.legend()
plt.show()

# %% [markdown]
# As can be seen from the above figure, the predicted results are very close to the real results, so the model can be considered accurate.

# %%
plt.figure(figsize=(16,9))
plt.plot(FS_2017['t'],FS_2017['pred_GHI']-FS_2017['data'])
plt.title('Prediction Error - HalfHourSolarRadiation2017')
plt.show()

# %% [markdown]
# From the results, it can be considered that the prediction error is larger in the middle and smaller at both ends.

# %% [markdown]
# **Use the error metrics defined below to evaluate the model.**

# %%
def NMBE(true_value,model_value):
    diffs = []
    for i in range(len(true_value)):
        diffs.append(true_value[i]-model_value[i])
    NMBE_value = np.sum(diffs)/(len(true_value)*np.mean(true_value))
    return NMBE_value


def NMAE(true_value,model_value):
    diffs = []
    for i in range(len(true_value)):
        diffs.append(abs(true_value[i]-model_value[i]))
    NMAE_value = np.sum(diffs)/(len(true_value)*np.mean(true_value))
    return NMAE_value

# %%
#for solar radiation, we only do the calculation for solar elevation greater than or equal to 10 degrees
FS_2017['Elevation'] = solar_radia2017['Elevation']
solar_radia_pred_df = FS_2017[FS_2017['Elevation']>=10].reset_index(drop=True)

#calculate NMBE
NMBE_value = NMBE(solar_radia_pred_df['data'],solar_radia_pred_df['pred_GHI'])
print('NMBE: ',NMBE_value)

#calculate NMAE
NMAE_value = NMAE(solar_radia_pred_df['data'],solar_radia_pred_df['pred_GHI'])
print('NMAE: ',NMAE_value)
# Out:
# NMBE:  0.0005764058614954701
# NMAE:  0.10672634392416983

# %% [markdown]
# NMBE (Normalized Mean Bias Error): This value is 0.000576, which is close to zero, indicating that the average bias of the model is very small. This means that the average deviation between the model's predictions and actual observations is very close to zero, and the model can be said to have very little deviation.
#
# NMAE (Normalized Mean Absolute Error, standardized mean absolute error): This value is 0.1067, which is also relatively small, indicating that the average absolute error of the model is overall small.

# %% [markdown]
# **Use the models you have developed for 2017 to see how they perform for the 2018 data, the out of sample data. Comment on the differences in the error metrics**

# %%
solar_radia2018 = pd.read_excel('HalfHourSolarRadiation2018.xlsx',sheet_name='Sheet1')

FS_2018 = calculate_fourier_series(solar_radia2018['Solar'],FS_2017.shape[0]+time_intervals,frequencies)
FS_2018['pred_Solar'] = FS_2018['model'] + best_arma.predict(FS_2018['t'][0],FS_2017.shape[0]+solar_radia2018.shape[0]-1)
FS_2018
# Out:
#        data      t           1        364         365        366         730  \
# 0       0.0  17521 -128.684598  86.590490 -258.296451  87.507336  101.027984
# 1       0.0  17522 -128.679205  84.624869 -248.826497  82.996940   85.964849
# 2       0.0  17523 -128.673795  81.219205 -235.099052  77.058663   65.043352
# 3       0.0  17524 -128.668368  76.431452 -217.348997  69.794666   39.689258
# 4       0.0  17525 -128.662925  70.343081 -195.880040  61.329920   11.630406
# ...     ...    ...         ...        ...         ...        ...         ...
# 17515   0.0  35036 -128.711318  74.524836 -238.781183  86.847153   69.516971
# 17516   0.0  35037 -128.706007  79.760109 -251.502537  90.111545   89.397578
# 17517   0.0  35038 -128.700680  83.638122 -259.920612  91.825656  103.185887
# 17518   0.0  35039 -128.695336  86.092883 -263.891375  91.959996  109.942249
# 17519   0.0  35040 -128.689975  87.082619 -263.346882  90.512253  109.206229
#
#            model  pred_Solar
# ...

# %%
plt.figure(figsize=(16,9))
plt.plot(FS_2018['t'],FS_2018['data'],label='original')
plt.plot(FS_2018['t'],FS_2018['pred_Solar'],label='predict')
plt.title('Original V.S Predict - HalfHourSolarRadiation2018')
plt.legend()
plt.show()

# %% [markdown]
# The figure above shows the model trained based on the 2017 data in 2018.
#
# It can be considered that the predicted value does not fit the real value very well, but the trend shown is similar to the trend of the real value.

# %%
plt.figure(figsize=(16,9))
plt.plot(FS_2018['t'],FS_2018['pred_Solar']-FS_2018['data'])
plt.title('Prediction Error - HalfHourSolarRadiation2018')
plt.show()

# %% [markdown]
# From the visualization results, the prediction error of the 2018 data is smaller than that of the 2017 data, so it can be considered that the accuracy of the model on the 2018 model is lower than that of the 2017 model.

# %%
FS_2018['Elevation'] = solar_radia2018['Elevation']

solar_radia_pred_df2018 = FS_2018[FS_2018['Elevation']>=10].reset_index(drop=True)

#calculate NMBE
NMBE_value = NMBE(solar_radia_pred_df2018['data'],solar_radia_pred_df2018['pred_Solar'])
print('NMBE: ',NMBE_value)

#calculate NMAE
NMAE_value = NMAE(solar_radia_pred_df2018['data'],solar_radia_pred_df2018['pred_Solar'])
print('NMAE: ',NMAE_value)
# Out:
# NMBE:  -0.03731455570097423
# NMAE:  0.3165742182418225

# %% [markdown]
# The forecast data results for 2018 are relatively accurate.
#
# But compared with the error metrics of the ARMA model on the 2017 data (NMBE: 0.0005764058614954701; NMAE: 0.10672634392416983), its performance on the 2018 data is worse.

# %% [markdown]
# The NMBE is about -0.0373, which means that the average predicted value of the model is slightly lower than the actual observed value, but the deviation is relatively small.
#
# NMAE is about 0.3166, which means that the percentage of the model's mean absolute error relative to the actual observed value is about 31.66%. This value can be used to evaluate the relative size of the model's prediction error. Typically, lower NMAE values indicate that the model's predictions are more accurate.

# %% [markdown]
# ## Question 2

# %%
#use the power spectrum to decide on the necessary frequencies
solar_farm = pd.read_excel('SolarFarm.xlsx',sheet_name='Sheet1')

num_frequencies = 50
PS_result_SolarFarm = calculate_dft(solar_farm.Output, num_frequencies)
PS_result_SolarFarm
# Out:
#     frequency         ai        bi     power
# 0           1  14.789658  0.146161  4.238366
# 1           2  -0.654833  0.725198  0.954719
# 2           3   0.188253 -0.908364  0.860564
# 3           4   0.295985 -0.158863  0.112845
# 4           5   0.376397 -0.178873  0.173670
# 5           6   0.609140 -0.127232  0.387239
# 6           7  -0.085552  0.011051  0.007441
# 7           8   0.471443  0.537855  0.511546
# 8           9  -0.070038  0.140644  0.024686
# 9          10   0.092156  0.076483  0.014342
# 10         11  -0.041695 -0.209945  0.045815
# 11         12  -0.034183  0.148884  0.023335
# 12         13  -0.076381 -0.160276  0.031522
# 13         14  -0.449367 -0.567574  0.524071
# 14         15   0.023546 -0.006046  0.000591
# 15         16   0.330498 -0.494301  0.353563
# 16         17   0.109381 -0.669173  0.459757
# 17         18  -0.731622 -0.298799  0.624552
# 18         19   0.156278  0.165745  0.051894
# 19         20   0.246235  0.161421  0.086689
# ...

# %%
#find out which frequencies are important

PS_result_SolarFarm.sort_values(by=['power'],ascending=False,inplace=True)
print(PS_result_SolarFarm)

plt.figure(figsize=(16,9))
plt.bar(PS_result_SolarFarm['frequency'], PS_result_SolarFarm['power'])
plt.title('Power Spectrum Result', fontsize=14)
plt.xlabel('Frequency', fontsize=14)
plt.ylabel('Power', fontsize=14)
plt.show()

#we can identify important frequencies from the below result and chart
important_frequencies = PS_result_SolarFarm['frequency'][:5].values
print('we can identify that the important frequencies for solar farm output are: ',important_frequencies)
# Out:
#     frequency         ai        bi     power
# 0           1  14.789658  0.146161  4.238366
# 1           2  -0.654833  0.725198  0.954719
# 2           3   0.188253 -0.908364  0.860564
# 21         22   0.105736  0.845238  0.725607
# 17         18  -0.731622 -0.298799  0.624552
# 33         34   0.221506  0.700209  0.539357
# 13         14  -0.449367 -0.567574  0.524071
# 7           8   0.471443  0.537855  0.511546
# 16         17   0.109381 -0.669173  0.459757
# 34         35  -0.298174 -0.564355  0.407404
# 44         45  -0.569391  0.251811  0.387615
# 5           6   0.609140 -0.127232  0.387239
# 15         16   0.330498 -0.494301  0.353563
# 31         32  -0.432586  0.380604  0.331990
# 46         47   0.188940  0.543942  0.331571
# 20         21  -0.513910  0.220348  0.312657
# 35         36  -0.417969 -0.344050  0.293069
# 36         37  -0.425556 -0.332561  0.291695
# 40         41   0.385312  0.345111  0.267567
# 25         26   0.417810  0.290567  0.258994
# ...

# %%
#find the Fourier series model

time_intervals = np.arange(1,solar_farm.shape[0]+1)

FS_solar_farm = calculate_fourier_series(solar_farm['Output'],time_intervals,frequencies)
FS_solar_farm
# Out:
#         data       t           1        364         365        366  \
# 0        0.0       1 -128.689080  87.103592 -262.816672  90.118503
# 1        0.0       2 -128.688185  87.083334 -262.161375  89.681625
# 2        0.0       3 -128.687289  87.021856 -261.381304  89.201830
# 3        0.0       4 -128.686392  86.919187 -260.476830  88.679347
# 4        0.0       5 -128.685496  86.775376 -259.448382  88.114425
# ...      ...     ...         ...        ...         ...        ...
# 105115   0.0  105116 -128.693551  86.586925 -264.212706  91.652530
# 105116   0.0  105117 -128.692658  86.772521 -264.184768  91.432963
# 105117   0.0  105118 -128.691764  86.917045 -264.031093  91.169641
# 105118   0.0  105119 -128.690870  87.020427 -263.751753  90.862689
# 105119   0.0  105120 -128.689975  87.082619 -263.346882  90.512253
#
#                730      model
# 0       108.351117 -91.142883
# 1       107.289754 -92.005190
# 2       106.024158 -93.031091
# 3       104.556739 -94.218292
# ...

# %% [markdown]
# Similarly, use the AIC criterion to estimate the parameters of the ARMA model, ie (p, q), and traverse the model parameters that minimize the AIC value

# %%
import statsmodels.api as sm
from statsmodels.tsa.arima_model import ARMA

# Calculate the residuals
FS_solar_farm['residual'] = FS_solar_farm['data'] - FS_solar_farm['model']

# Use the AIC criterion to estimate the parameters of the ARMA model, ie (p,q)

AIC_value = []

for ari in range(0,5):
    for maj in range(0,5):
        try:
            arma_object = ARMA(FS_solar_farm['residual'],order=(ari,maj)).fit()
            AIC_value.append([ari,maj,arma_object.aic])
        except:
            print('Wrong Parameters')

print(AIC_value)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:7: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:7: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,

# %% [markdown]
# According to the results, it can be seen that when (p, q) = (2, 1), the AIC value is the smallest. Therefore, (2,1) is the optimal model parameter of ARMA.

# %%
# get the best armr model
#best_arma = ARMA(FS_solar_farm['residual'].tolist(),order=(2,1)).fit()

#forecast one step ahead for the residuals
FS_solar_farm['pred_residuals'] = best_arma.predict(0,FS_solar_farm.shape[0]-1)

#add that to the Fourier series model
FS_solar_farm['pred_Output'] = FS_solar_farm['model'] + FS_solar_farm['pred_residuals']
FS_solar_farm
# Out:
#         data       t           1        364         365        366  \
# 0        0.0       1 -128.689080  87.103592 -262.816672  90.118503
# 1        0.0       2 -128.688185  87.083334 -262.161375  89.681625
# 2        0.0       3 -128.687289  87.021856 -261.381304  89.201830
# 3        0.0       4 -128.686392  86.919187 -260.476830  88.679347
# 4        0.0       5 -128.685496  86.775376 -259.448382  88.114425
# ...      ...     ...         ...        ...         ...        ...
# 105115   0.0  105116 -128.693551  86.586925 -264.212706  91.652530
# 105116   0.0  105117 -128.692658  86.772521 -264.184768  91.432963
# 105117   0.0  105118 -128.691764  86.917045 -264.031093  91.169641
# 105118   0.0  105119 -128.690870  87.020427 -263.751753  90.862689
# 105119   0.0  105120 -128.689975  87.082619 -263.346882  90.512253
#
#                730      model   residual  pred_residuals  pred_Output
# 0       108.351117 -91.142883  91.142883        5.315180   -85.827703
# ...

# %%
solar_farm_pred = FS_solar_farm[FS_solar_farm['data']>0].reset_index(drop=True)

#calculate NMBE
NMBE_value = NMBE(solar_farm_pred['data'],solar_farm_pred['pred_Output'])
print('NMBE: ',NMBE_value)

#calculate NMAE
NMAE_value = NMAE(solar_farm_pred['data'],solar_farm_pred['pred_Output'])
print('NMAE: ',NMAE_value)
# Out:
# NMBE:  -4.589187327708524
# NMAE:  7.175711416139246

# %% [markdown]
# ## Question 3

# %%
wind_farm = pd.read_excel('SnowtownWindFarm.xlsx',sheet_name='Sheet1')
wind_farm
# Out:
#         Snowtown
# 0      84.198322
# 1      84.117132
# 2      81.609137
# 3      79.826108
# 4      75.148393
# ...          ...
# 17515  38.392713
# 17516  46.934388
# 17517  53.936237
# 17518  58.116488
# 17519  58.070410
#
# [17520 rows x 1 columns]

# %%
#Use the power spectrum file from above to show that there is no significant seasonality in the data

num_frequencies = 50

PS_result_windFarm = calculate_dft(wind_farm.Snowtown, num_frequencies)
PS_result_windFarm
# Out:
#     frequency         ai        bi      power
# 0           1  36.605356  0.756815   1.520784
# 1           2   2.995149  0.352905   9.095458
# 2           3   1.909071  1.988578   7.598997
# 3           4   1.435534  1.411307   4.052545
# 4           5  -1.581604  1.127824   3.773458
# 5           6   1.341553 -1.480244   3.990889
# 6           7   0.758636 -1.026324   1.628870
# 7           8  -0.435229  1.177705   1.576414
# 8           9  -1.719059 -2.022673   7.046370
# 9          10   1.534883  2.130692   6.895716
# 10         11  -1.663518 -1.077311   3.927893
# 11         12   2.262251  1.021960   6.162180
# 12         13   0.616326  0.277349   0.456780
# 13         14   0.870656 -1.763459   3.867831
# 14         15  -3.419908  2.938028  20.327782
# 15         16  -1.360392 -1.828568   5.194326
# 16         17  -0.998102 -1.263728   2.593218
# 17         18   4.184620 -1.569606  19.974710
# 18         19  -4.195564  0.177137  17.634132
# ...

# %% [markdown]
# From the above results, there is no significant seasonality in the data.

# %%
#find out which frequencies are important

PS_result_windFarm.sort_values(by=['power'],ascending=False,inplace=True)
print(PS_result_windFarm)

plt.figure(figsize=(16,9))
plt.bar(PS_result_windFarm['frequency'], PS_result_windFarm['power'])
plt.title('Power Spectrum Result', fontsize=14)
plt.xlabel('Frequency', fontsize=14)
plt.ylabel('Power', fontsize=14)
plt.grid(True)
plt.show()

#we can identify important frequencies from the below result and chart
important_frequencies = PS_result_windFarm['frequency'][:5].values
print('we can identify that 5 most important frequencies are: ',important_frequencies)
# Out:
#     frequency         ai        bi      power
# 45         46  -3.636081  5.010479  38.325991
# 19         20   4.103955 -3.316293  27.840249
# 34         35   3.449838  3.658955  25.289334
# 14         15  -3.419908  2.938028  20.327782
# 17         18   4.184620 -1.569606  19.974710
# 38         39  -1.027784 -4.157671  18.342569
# 18         19  -4.195564  0.177137  17.634132
# 20         21   2.196765  3.527584  17.269620
# 25         26  -3.555153 -0.983289  13.605972
# 26         27   2.834060  1.757737  11.121537
# 43         44  -3.289056  0.461414  11.030790
# 35         36  -0.065630 -3.263489  10.654670
# 44         45   2.455552 -2.048016  10.224104
# 1           2   2.995149  0.352905   9.095458
# 33         34   3.010750  0.119057   9.078790
# 2           3   1.909071  1.988578   7.598997
# 8           9  -1.719059 -2.022673   7.046370
# 9          10   1.534883  2.130692   6.895716
# 24         25   2.482703  0.624639   6.553988
# ...

# %%
import statsmodels.api as sm
from statsmodels.tsa.ar_model import AutoReg
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# Calculate the acf and pacf of the wind_farm data to determine the optimal order p of the AR model
acf_plot = plot_acf(wind_farm['Snowtown'], lags=100)

# According to the autoregressive graph, the lag value should be selected as [1,2,3,4,5,45]
lags = [1,2,3,4,5,45]

# %% [markdown]
# The autocorrelation analysis reveals distinct patterns within the time series data across different lag intervals. In the initial phase, spanning from approximately 0 to 30 lags, the autocorrelation exhibits a noteworthy decline, gradually diminishing from a value of 1.0 to a level slightly below 0.2. This decline suggests a strong positive correlation between observations at adjacent time points, indicative of a prominent short-term temporal dependence within the data.
#
# Subsequently, within the temporal interval extending from 30 to around 50 lags, there is a modest increase in autocorrelation, rising to approximately 0.3. This observed increase may signify a moderate resurgence in the correlation between observations at these specific lags, potentially indicating some intermediate-term temporal structure.
#
# However, the most notable pattern emerges in the range of 50 to 70 lags, where autocorrelation experiences a consistent and pronounced decrease, eventually reaching negative values. This decline points to a significant reversal in the temporal dependencies, suggesting that observations at these lags become inversely related, possibly reflecting a cyclical or oscillatory behavior in the data.
#
# Remarkably, as the analysis progresses beyond 70 lags and approaches the range of 70 to 100, there is a discernible upturn in the autocorrelation, culminating around lag 90 with a value close to 0. This resurgence in autocorrelation implies a renewed positive correlation between observations separated by these lags, potentially hinting at the emergence of a longer-term temporal structure in the data.

# %%
best_ar = AutoReg(wind_farm['Snowtown'], lags = lags, seasonal = False).fit()
print(best_ar.summary())
# Out:
#                             AutoReg Model Results
# ...
# Dep. Variable:               Snowtown   No. Observations:                17520
# Model:             Restr. AutoReg(45)   Log Likelihood              -63139.604
# Method:               Conditional MLE   S.D. of innovations              8.973
# Date:                Mon, 04 Sep 2023   AIC                              4.389
# Time:                        01:44:03   BIC                              4.393
# Sample:                            45   HQIC                             4.390
#                                 17520
# ...
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# intercept        1.4934      0.127     11.793      0.000       1.245       1.742
# Snowtown.L1      1.1481      0.008    151.708      0.000       1.133       1.163
# Snowtown.L2     -0.2630      0.012    -22.838      0.000      -0.286      -0.240
# ...

# %% [markdown]
# According to the results, it can be seen that the results are significantly related to lag1, lag2, lag3, and lag45.

# %% [markdown]
# Use the AIC criterion to estimate the parameters of the ARMA model, that is, (p, q), and traverse the model parameters that minimize the AIC value.

# %%
from statsmodels.tsa.arima_model import ARMA

AIC_value = []

for ari in range(0,5):
    for maj in range(0,5):
        try:
            arma_object = ARMA(wind_farm['Snowtown'],order=(ari,maj)).fit()
            AIC_value.append([ari,maj,arma_object.aic])
        except:
            print('Wrong Parameters')

print(AIC_value)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
# 参数错误
# 参数错误
# 参数错误
# ...

# %% [markdown]
# According to the results, when (p, q) = (4, 0), the AIC value is the smallest. Therefore, (4,0) is the best model parameter for ARMA.

# %%
best_arma = ARMA(wind_farm['Snowtown'],order=(4,0)).fit()
print(best_arma.summary())
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/statsmodels/tsa/arima_model.py:472: FutureWarning:
# statsmodels.tsa.arima_model.ARMA and statsmodels.tsa.arima_model.ARIMA have
# been deprecated in favor of statsmodels.tsa.arima.model.ARIMA (note the .
# between arima and model) and
# statsmodels.tsa.SARIMAX. These will be removed after the 0.12 release.
#
# statsmodels.tsa.arima.model.ARIMA makes use of the statespace framework and
# is both well tested and maintained.
#
# To silence this warning and continue using ARMA and ARIMA until they are
# removed, use:
#
# import warnings
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARMA',
#                         FutureWarning)
# warnings.filterwarnings('ignore', 'statsmodels.tsa.arima_model.ARIMA',
#                         FutureWarning)
#
#   warnings.warn(ARIMA_DEPRECATION_WARN, FutureWarning)
#                               ARMA Model Results
# ...

# %% [markdown]
# Certainly, here's the explanation of the provided results broken down into paragraphs for clarity:
#
# The dependent variable (Dep. Variable) in this analysis represents the primary focus of the model, which is the variable we aim to predict or model. In this context, it is denoted as "Snowtown."
#
# The number of observations (No. Observations) signifies the total data points available for analysis, with a substantial count of 17,520 observations.
#
# The model type (Model) specified here is an ARMA(4, 0) model. This implies that the model incorporates both an autoregressive component (AR) and a moving average component (MA). Specifically, ARMA(4, 0) indicates the presence of a 4th-order autoregressive component and no moving average component.
#
# For estimating the model parameters, the method employed is css-mle, which stands for conditional maximum likelihood estimation method.
#
# The standard deviation of the innovations (S.D. of innovations) indicates the variability or dispersion of the error term within the model. In this case, the standard deviation is 8.982.
#
# The date (Date) associated with the generation of these analysis results is provided for reference.
#
# The AIC (Akaike Information Criterion) and BIC (Bayesian Information Criterion) are model selection criteria. AIC, with a value of 126654.266, is employed to assess and compare the goodness of fit among different models, with lower values indicating better fit. Meanwhile, the BIC has a value of 126700.893.
#
# The sample position (Sample) denotes the starting point in the dataset for the analysis, and in this instance, it initiates from the 0th observation.
#
# Moving on to the parameter estimation results:
#
# The constant term (const) serves as the model's intercept and is found to be 36.6608.
#
# The autoregressive coefficients are presented as ar.L1.Snowtown (1.1528), ar.L2.Snowtown (-0.2644), ar.L3.Snowtown (0.0911), and ar.L4.Snowtown (-0.0335), corresponding to the first, second, third, and fourth-order autoregressive components, respectively.
#
# Finally, information regarding the model's roots or eigenvalues is provided. These roots are essential for assessing the stability of the model and understandi" variable in the dataset.the stability of the model.

# %%
ar_preds = []
for i in range(100,500):
    ar_preds.append(best_ar.params['intercept']+best_ar.params['Snowtown.L1']*wind_farm['Snowtown'][i-1]+best_ar.params['Snowtown.L2']*wind_farm['Snowtown'][i-2]+best_ar.params['Snowtown.L3']*wind_farm['Snowtown'][i-3]+best_ar.params['Snowtown.L4']*wind_farm['Snowtown'][i-4]+best_ar.params['Snowtown.L5']*wind_farm['Snowtown'][i-5]+best_ar.params['Snowtown.L45']*wind_farm['Snowtown'][i-45])

print('AR Model NMBE: ',NMBE(wind_farm['Snowtown'][100:500].values,np.array(ar_preds)))
print('AR Model NMAE: ',NMAE(wind_farm['Snowtown'][100:500].values,np.array(ar_preds)))
# Out:
# AR Model NMBE:  -0.0002013561053139933
# AR Model NMAE:  0.13404619691332592

# %% [markdown]
# The value of NMBE is -0.000201, which is close to zero, which means that the average deviation of the model is very small. Negative values indicate that the model's predictions slightly underestimate the actual observations, but the bias is very close to zero.
#
# The value of NMAE is 0.134, which is relatively small, indicating that the mean absolute error of the model is also relatively small.

# %%
plt.figure(figsize=(16,9))
plt.plot(range(100,500),wind_farm['Snowtown'][100:500].values,label='original')
plt.plot(range(100,500),ar_preds,label='predict')
plt.title('Original V.S Predict - The Best AR Model')
plt.legend()
plt.show()

# %% [markdown]
# From the above figure, for snowtownwindfarm, the predicted value is very close to the original value. There is reason to believe that the performance of the model is no problem.

# %%
arma_preds = best_arma.predict(100,500)

print('ARMA Model NMBE: ',NMBE(wind_farm['Snowtown'][100:500].values,arma_preds.values))
print('ARMA Model NMAE: ',NMAE(wind_farm['Snowtown'][100:500].values,arma_preds.values))
# Out:
# ARMA Model NMBE:  0.0009135746653356808
# ARMA Model NMAE:  0.13451608620153263

# %% [markdown]
# ARMA Model NMBE (Normalized Mean Bias Error): This metric, with an approximate value of 0.0009, serves as an indicator of the presence of bias or systematic error within the model's predictions. In this particular context, the observed NMBE value suggests a minuscule degree of bias, underscoring that, on average, the forecasts generated by the ARMA model closely align with the actual values.
#
# ARMA Model NMAE (Normalized Mean Absolute Error): This metric, registering an approximate value of 0.1345, quantifies the absolute magnitude of errors inherent in the model's predictions. A NMAE value of 0.1345 signifies that, on average, the ARMA model's forecasts exhibit an absolute error of approximately 13.45% concerning the actual values.

# %% [markdown]
# **Compare**
#
# The NMBE of the AR model is -0.0002014, which is close to zero, indicating that the prediction deviation of the model is very small and can basically be considered accurate.
# The NMBE for the ARMA model is 0.0009136, which is slightly off zero, but also very close to zero. This means that the forecast bias of the ARMA model is also relatively small, but slightly higher.
#
# The NMAE of the AR model is 0.1340, which means that the mean absolute error is relatively small, and the prediction of the model is relatively accurate on average.
# The NMAE of the ARMA model is 0.1345, which is slightly higher than that of the AR model, but the difference is not large, which also shows that the average absolute error of the model is relatively small.

# %%
plt.figure(figsize=(16,9))
plt.plot(range(100,500),wind_farm['Snowtown'][100:500].values,label='original')
plt.plot(range(100,500),arma_preds[:-1],label='predict')
plt.title('Original V.S Predict - The Best ARMA Model')
plt.legend()
plt.show()

# %% [markdown]
# The picture above shows the comparison between the predicted value of best arma and the original data. It can be considered that the best arma model predicts very well.

# %%
plt.figure(figsize=(16,9))
plt.plot(range(100,500),wind_farm['Snowtown'][100:500].values,label='original')
plt.plot(range(100,500),ar_preds,label='AR_predict')
plt.plot(range(100,500),arma_preds[:-1],label='ARMA_predict')
plt.title('Original V.S Predict - AR and ARMA Models')
plt.legend()
plt.show()

# %% [markdown]
# The above figure shows the visual comparison of the original data, the prediction results of the AR model and the prediction results of the ARMA model.
#
# Judging from the results, the predicted values of AR_predict and ARMA_predict are basically the same, and there are only a few differences between the two and the original data.

# %% [markdown]
# **Is there a difference in the number of parameters to estimate in the two models? Is there a difference in the
# number of parameters to estimate in the two models? If so, is it worth it to us
# the one with extra parameters?**
#
# According to the above results, the optimal AR model and the optimal ARMA model are very similar, and the performance of the two indicators of NMBE and NMAE is also very close.
#
# This is because the lags parameter of the optimal AR model is [1,2,3,4,5,45], and the (p,q) parameter of the optimal ARMA model is (4, 0), which means, The optimal ARMA model is actually an AR model, and the lags parameter is [1,2,3,4].
#
# It can be seen that the parameters of the two models themselves are very close, which is why the performance of the two is almost the same.

# %% [markdown]
# The optimal AR model has a lags parameter set of [1, 2, 3, 4, 5, 45], while the optimal ARMA model has a (p, q) parameter set of (4, 0), which essentially represents an AR model with lags [1, 2, 3, 4].
#
# Given that the parameters of the two models are very similar, with the ARMA model being a subset of the AR model in terms of parameters, it raises the question of whether it is worth using the model with the additional parameters. In this context, it may not be necessary to opt for the ARMA model with extra parameters if the performance of both models, as indicated by NMBE and NMAE, is nearly identical.
#
# The choice between these models should consider factors beyond parameter count, such as model interpretability, computational efficiency, and the principle of parsimony (Occam's Razor), which favors simpler models when their performance is comparable. Therefore, if the AR model and the ARMA model exhibit almost identical performance, it might be more practical to select the simpler AR model to avoid unnecessary complexity and computation, unless there are specific theoretical or practical reasons to choose the ARMA model with additional parameters.
